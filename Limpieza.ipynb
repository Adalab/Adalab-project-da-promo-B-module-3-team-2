# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./datos/bikes.csv", index_col = 0)

# %%
df.head(16)
# Out:
#     instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0         1  01-01-2018  spring   0     1        0        6           0
# 1         2  02-01-2018  spring   0     1        0        0           0
# 2         3  03-01-2018  spring   0     1        0        1           1
# 3         4  04-01-2018  spring   0     1        0        2           1
# 4         5  05-01-2018  spring   0     1        0        3           1
# 5         6  06-01-2018  spring   0     1        0        4           1
# 6         7  07-01-2018  spring   0     1        0        5           1
# 7         8  08-01-2018  spring   0     1        0        6           0
# 8         9  09-01-2018  spring   0     1        0        0           0
# 9        10  10-01-2018  spring   0     1        0        1           1
# 10       11  11-01-2018  spring   0     1        0        2           1
# 11       12  12-01-2018  spring   0     1        0        3           1
# ...

# %%
df["season"].value_counts()
# Out:
# autumn    188
# summer    184
# spring    180
# winter    178
# Name: season, dtype: int64

# %%
df["weekday"].unique()
# Out:
# array([6, 0, 1, 2, 3, 4, 5], dtype=int64)

# %%
df["mnth"].value_counts()
# Out:
# 1     62
# 3     62
# 5     62
# 7     62
# 8     62
# 10    62
# 12    62
# 4     60
# 6     60
# 9     60
# 11    60
# 2     56
# Name: mnth, dtype: int64

# %%
df.describe()
# Out:
#           instant          yr        mnth     holiday     weekday  workingday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    0.500000    6.526027    0.028767    2.997260    0.683562
# std    210.877136    0.500343    3.450215    0.167266    2.006161    0.465405
# min      1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%    183.250000    0.000000    4.000000    0.000000    1.000000    0.000000
# 50%    365.500000    0.500000    7.000000    0.000000    3.000000    1.000000
# 75%    547.750000    1.000000   10.000000    0.000000    5.000000    1.000000
# max    730.000000    1.000000   12.000000    1.000000    6.000000    1.000000
#
#        weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     1.394521   20.319259   23.726322   62.765175   12.763620
# std      0.544807    7.506729    8.150308   14.237589    5.195841
# ...

# %%
df.describe(include = "O")
# Out:
#             dteday  season
# count          730     730
# unique         730       4
# top     01-01-2018  autumn
# freq             1     188

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    object
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(10), object(2)
# memory usage: 97.0+ KB

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %% [markdown]
# CASTEAMOS la variable dteday a DATETIME.

# %%
df['dteday'] = pd.to_datetime(df['dteday'])
# Out:
# C:\Users\LARA\AppData\Local\Temp\ipykernel_5264\3022120740.py:1: UserWarning: Parsing '13-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['dteday'] = pd.to_datetime(df['dteday'])
# C:\Users\LARA\AppData\Local\Temp\ipykernel_5264\3022120740.py:1: UserWarning: Parsing '14-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['dteday'] = pd.to_datetime(df['dteday'])
# C:\Users\LARA\AppData\Local\Temp\ipykernel_5264\3022120740.py:1: UserWarning: Parsing '15-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['dteday'] = pd.to_datetime(df['dteday'])
# C:\Users\LARA\AppData\Local\Temp\ipykernel_5264\3022120740.py:1: UserWarning: Parsing '16-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['dteday'] = pd.to_datetime(df['dteday'])
# ...

# %%
df.head(2)
# Out:
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2018-01-01  spring   0     1        0        6           0
# 1        2 2018-02-01  spring   0     1        0        0           0
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
#
#    cnt
# 0  985
# 1  801

# %%
# comprobamos que hemos modificado el tipo de la columna a datetime.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    datetime64[ns]
#  2   season      730 non-null    object
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(10), object(1)
# memory usage: 97.0+ KB

# %%
df.shape
# Out:
# (730, 16)

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df['yr'].value_counts()
# Out:
# 0    365
# 1    365
# Name: yr, dtype: int64

# %%
df['dteday'].value_counts()
# Out:
# 2018-01-01    1
# 2019-04-25    1
# 2019-04-27    1
# 2019-04-28    1
# 2019-04-29    1
#              ..
# 2018-03-09    1
# 2018-04-09    1
# 2018-05-09    1
# 2018-06-09    1
# 2019-12-31    1
# Name: dteday, Length: 730, dtype: int64

# %% [markdown]
# Vamos a corregir los valores de season  y además los casteamos a int.

# %%
season_cambio = {"spring":4, "summer":1, "autumn": 2, "winter":3}

# %% [markdown]
# PRIMAVERA: 1
# VERANO: 2
# OTOÑO: 3
# INVIERNO: 4

# %%
df["season"]=df["season"].map(season_cambio)

# %%
df.head()
# Out:
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2018-01-01       4   0     1        0        6           0
# 1        2 2018-02-01       4   0     1        0        0           0
# 2        3 2018-03-01       4   0     1        0        1           1
# 3        4 2018-04-01       4   0     1        0        2           1
# 4        5 2018-05-01       4   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %% [markdown]
# Vamos a redondear los float a dos decimales.

# %%
df = df.round(2)

# %%
df.head(10)
# Out:
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2018-01-01       4   0     1        0        6           0
# 1        2 2018-02-01       4   0     1        0        0           0
# 2        3 2018-03-01       4   0     1        0        1           1
# 3        4 2018-04-01       4   0     1        0        2           1
# 4        5 2018-05-01       4   0     1        0        3           1
# 5        6 2018-06-01       4   0     1        0        4           1
# 6        7 2018-07-01       4   0     1        0        5           1
# 7        8 2018-08-01       4   0     1        0        6           0
# 8        9 2018-09-01       4   0     1        0        0           0
# 9       10 2018-10-01       4   0     1        0        1           1
#
#    weathersit   temp  atemp    hum  windspeed  casual  registered   cnt
# 0           2  14.11  18.18  80.58      10.75     331         654   985
# ...

# %%
df.to_pickle("./datos/limpieza.pkl")

# %% [markdown]
# LUNES - 1
# DOMINGO - 7

# %%
semana_cambio = {6:1, 0:2, 1:3, 2:4, 3:5, 4:6, 5:7}

# %%
df["weekday"]=df["weekday"].map(semana_cambio)

# %%
df.head(30)
# Out:
#     instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0         1 2018-01-01       4   0     1        0        1           0
# 1         2 2018-02-01       4   0     1        0        2           0
# 2         3 2018-03-01       4   0     1        0        3           1
# 3         4 2018-04-01       4   0     1        0        4           1
# 4         5 2018-05-01       4   0     1        0        5           1
# 5         6 2018-06-01       4   0     1        0        6           1
# 6         7 2018-07-01       4   0     1        0        7           1
# 7         8 2018-08-01       4   0     1        0        1           0
# 8         9 2018-09-01       4   0     1        0        2           0
# 9        10 2018-10-01       4   0     1        0        3           1
# 10       11 2018-11-01       4   0     1        0        4           1
# 11       12 2018-12-01       4   0     1        0        5           1
# ...

# %%
df.to_csv("./datos/limpieza.csv")

# %%
df2=pd.read_csv('./datos/limpieza_holidays.csv', sep=';')
df2.head()
# Out:
#                                                                                                                             limpieza
# NaN   instant dteday     season yr mnth holiday weekday workingday weathersit temp  atemp hum   windspeed casual registered      cnt
# 0.0   1       2018-01-01 4      0  1    1       1       0          2          14.11 18.18 80.58 10.75     331    654             985
# 1.0   2       2018-02-01 4      0  1    0       2       0          2          14.9  17.69 69.61 16.65     131    670             801
# 2.0   3       2018-03-01 4      0  1    0       3       1          1          8.05  9.47  43.73 16.64     120    1229           1349
# 3.0   4       2018-04-01 4      0  1    0       4       1          1          8.2   10.61 59.04 10.74     108    1454           1562
